# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn import datasets
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC

# %%
xtrain = pd.read_pickle(open('Desktop/X_train.pickle', 'rb'))
ytrain = pd.read_pickle(open('Desktop/y_train.pickle', 'rb'))

# %%
xtrain.head()
# Out:
#    order_number order_dow order_hour_of_day  days_since_prior_order  \
# 0            11         4                 8                      14
# 1            15         1                11                      30
# 2             5         0                11                       6
# 3            21         2                11                       6
# 4             4         1                14                      10
#
#   num_orders  avg_num_reordered  avg_num_pids  dow_0  dow_1  dow_2    ...      \
# 0         10                  4             5      0      3      2    ...
# 1         14                  6            13      0      5      5    ...
# 2          4                  3             9      1      1      0    ...
# 3         20                  6            10      6      5      2    ...
# 4          3                  4            16      0      1      0    ...
#
#        emb_90      emb_91      emb_92      emb_93      emb_94      emb_95  \
# ...

# %%
xtrain = xtrain.values

# %%
xtrain
# Out:
# array([[11, '4', '8', ..., -15.229999542236328, -27.940000534057617,
#         -1.2200000286102295],
#        [15, '1', '11', ..., -31.190000534057617, 18.959999084472656,
#         25.860000610351562],
#        [5, '0', '11', ..., 3.2899999618530273, 26.969999313354492,
#         18.920000076293945],
#        ...,
#        [6, '4', '19', ..., 36.66999816894531, 20.510000228881836,
#         -1.0499999523162842],
#        [4, '1', '16', ..., 0.7699999809265137, 2.430000066757202,
#         -6.130000114440918],
#        [14, '6', '14', ..., -4.710000038146973, -13.3100004196167,
#         -27.81999969482422]], dtype=object)

# %%
ytrain
# Out:
# <131209x49689 sparse matrix of type '<class 'numpy.int32'>'
# 	with 837426 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### The following cell is the framework to run the OneVsRest classifier with multilabel

# %%
model = OneVsRestClassifier(LinearSVC(random_state=1), n_jobs=2)
model.fit(xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/jeremy/.local/lib/python3.5/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 344, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/jeremy/.local/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/home/jeremy/.local/lib/python3.5/site-packages/sklearn/externals/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/home/jeremy/.local/lib/python3.5/site-packages/sklearn/multiclass.py", line 80, in _fit_binary
#     estimator.fit(X, y)
# ...

# %%
model.predict(xtest)

# %% [markdown]
# Then will build a simple block to calculate the accuracy compared to y_test
